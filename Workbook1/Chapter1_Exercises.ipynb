# %% [markdown]
# EXERCISE 1

# %%
print('Hello world!') #the letter "P" should not be capitalized
# Out:
# Hello world!

# %%
print('Hello world!') #missing "("
# Out:
# Hello world!

# %%
print('Hello world!') #missing a "'"
# Out:
# Hello world!

# %%
print('Hello world!') #two apostrophes
# Out:
# Hello world!

# %% [markdown]
# EXERCISE 2

# %%
x = 43
x = x + 1
print(x)
44
# Out:
# 44
# 44

# %% [markdown]
# EXERCISE 3

# %%
x = 43
x = x + 1
print(x)
#change "x" into small letter
# Out:
# 44

# %%
# !git config --global user.name =  'Renesel Anoslay' #your full name
# !git config --global user.email = 'renesel.anoslay@students.isatu.edu.ph' #the email address you used in creating your GitHub account
#!git config --global user.password = 'xxx your TOKEN xxx' #password should be the token

# %%
# !git clone https://Anosaly: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@github.com/Anoslay/ICT110_BSCS2A_Anoslay.git
# Out:
# Cloning into 'ICT110_BSCS2A_Anoslay'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 6 (delta 0), pack-reused 0
# Receiving objects: 100% (6/6), 23.23 KiB | 11.62 MiB/s, done.
